# %% [markdown]
# # **데이터 전처리**

# %% [markdown]
# # git clone data

# %%
# !git clone https://github.com/huijunam/CJ_AI_hackathon.git
# Out:
# Cloning into 'CJ_AI_hackathon'...
# remote: Enumerating objects: 101, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 101 (delta 11), reused 10 (delta 1), pack-reused 69
# Receiving objects: 100% (101/101), 6.35 MiB | 12.07 MiB/s, done.
# Resolving deltas: 100% (39/39), done.

# %%
import pandas as pd

chatbot_data_1 = pd.read_excel('/content/CJ_AI_hackathon/data/source_data/8f3202096f1387c5.xlsx')
chatbot_data_2 = pd.read_excel('/content/CJ_AI_hackathon/data/source_data/ad8cb80ea8623bbe.xlsx')

# %%
chatbot_data_1.sample(n =10)
# Out:
#                                                 Sentence Emotion  Unnamed: 2  \
# 33624  길라임과 최순실 다니는 차움병원 손연재 떡돌리는 사진 떳다.왜 안티에이징 병윈에 떡...      혐오         NaN
# 24923                                     싱가폴봐라 얼마나 청정하냐      중립         NaN
# 30690                                            댓글감사합니다      행복         NaN
# 26748                                     주모 여기 손주 한병 추가      중립         NaN
# 38513             씨박...중차팔이 .폰팔이 새ㄲㅣ중 .. 인성 제대로된 새 ㄲㅣ못봤다      혐오         NaN
# 15965                    그런데 인터넷에 널린게 카카까는건데왜 안잡아가죠?흠...      분노         NaN
# 15948          jtbc는 정유라 체포 단독보도하고 채널a는 치매노인 개소리 단독보도하네.      분노         NaN
# 11299                       우리나라최고의 타자가 메이저에선 마이너수준이란말인가      놀람         NaN
# 3171                                     어떤거 주의해야 하나요..?      공포         NaN
# 8752                                       그정도라면 ㅋㅋㅋㅋㅋㅋㅋ      놀람         NaN
#
#        Unnamed: 3  Unnamed: 4   공포  5468
# 33624         NaN         NaN  NaN   NaN
# 24923         NaN         NaN  NaN   NaN
# 30690         NaN         NaN  NaN   NaN
# 26748         NaN         NaN  NaN   NaN
# 38513         NaN         NaN  NaN   NaN
# 15965         NaN         NaN  NaN   NaN
# 15948         NaN         NaN  NaN   NaN
# 11299         NaN         NaN  NaN   NaN
# 3171          NaN         NaN  NaN   NaN
# 8752          NaN         NaN  NaN   NaN

# %%
chatbot_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38594 entries, 0 to 38593
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Sentence    38594 non-null  object
#  1   Emotion     38594 non-null  object
#  2   Unnamed: 2  0 non-null      float64
#  3   Unnamed: 3  0 non-null      float64
#  4   Unnamed: 4  0 non-null      float64
#  5   공포          7 non-null      object
#  6   5468        7 non-null      float64
# dtypes: float64(4), object(3)
# memory usage: 2.1+ MB

# %%
chatbot_data_1.describe()
# Out:
#        Unnamed: 2  Unnamed: 3  Unnamed: 4          5468
# count         0.0         0.0         0.0      7.000000
# mean          NaN         NaN         NaN  10245.714286
# std           NaN         NaN         NaN  12506.947639
# min           NaN         NaN         NaN   4830.000000
# 25%           NaN         NaN         NaN   5348.000000
# 50%           NaN         NaN         NaN   5665.000000
# 75%           NaN         NaN         NaN   5967.500000
# max           NaN         NaN         NaN  38594.000000

# %%
chatbot_data_1.count()
# Out:
# Sentence      38594
# Emotion       38594
# Unnamed: 2        0
# Unnamed: 3        0
# Unnamed: 4        0
# 공포                7
# 5468              7
# dtype: int64

# %%
# 필요없는 열 삭제
chatbot_data_1= chatbot_data_1.iloc[:,:2]
chatbot_data_1
# Out:
#                                                 Sentence Emotion
# 0                               언니 동생으로 부르는게 맞는 일인가요..??      공포
# 1                                           그냥 내 느낌일뿐겠지?      공포
# 2                                         아직너무초기라서 그런거죠?      공포
# 3                                          유치원버스 사고 낫다던데      공포
# 4                                            근데 원래이런거맞나요      공포
# ...                                                  ...     ...
# 38589               솔직히 예보 제대로 못하는 데 세금이라도 아끼게 그냥 폐지해라..      혐오
# 38590                                        재미가 없으니 망하지      혐오
# 38591  공장 도시락 비우생적임 아르바이트했는데 화장실가성 손도 않씯고 재료 담고 바닥 떨어...      혐오
# 38592               코딱지 만한 나라에서 지들끼리 피터지게 싸우는 센징 클래스 ㅉㅉㅉ      혐오
# 38593               와이프도 그렇고 댓글 다 볼텐데 이휘재 좀 하차 하라고 전해주세요      혐오
#
# [38594 rows x 2 columns]

# %%
chatbot_data_1.isnull().sum() # 결측치 확인
# Out:
# Sentence    0
# Emotion     0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

chatbot_data_1['Emotion'].value_counts()
# Out:
# 행복    6037
# 놀람    5898
# 분노    5665
# 공포    5468
# 혐오    5429
# 슬픔    5267
# 중립    4830
# Name: Emotion, dtype: int64

# %%
chatbot_data_2.sample(n =10)
# Out:
#       Unnamed: 0                                         Unnamed: 1  \
# 32268          S                                     사장님. 누구 기다리세요?
# 46806        NaN                                                 네?
# 32615        NaN                                    그동안 많이 불편했죠?...
# 52329          S                                 여기야! 여기가 좋겠어! 아마도.
# 25930        NaN  그건 아니지. 야. 옷을 좀 노티나게 입어봐. 맨날 애처럼 막 입고 다니니까 더 그...
# 3137         NaN    그런~가? 가격을 틀리는 것도 정도껏이지 어떻게 장난감 하나가 300만원이 되는거야?
# 51063        NaN                                            뭐? 어째서?
# 15790        NaN             그래. 무슨 말인지 알겠어. 근데.. 너의 추억까지 다치게 하지마.
# 25451          S     부사장 덕분에 어려운 계약이 쉽게 성사됐어. 잘했어. 덕분에 큰 고비 하나 넘겼네.
# 42784        NaN                                      나 지금 장난 아니거든?
#
#       Unnamed: 2  Unnamed: 3  Unnamed: 4  행복  중립  슬픔  공포  혐오  분노  놀람
# 32268         중립         NaN         NaN NaN NaN NaN NaN NaN NaN NaN
# 46806         놀람         NaN         NaN NaN NaN NaN NaN NaN NaN NaN
# 32615         중립         NaN         NaN NaN NaN NaN NaN NaN NaN NaN
# 52329         놀람         NaN         NaN NaN NaN NaN NaN NaN NaN NaN
# 25930         중립         NaN         NaN NaN NaN NaN NaN NaN NaN NaN
# 3137          분노         NaN         NaN NaN NaN NaN NaN NaN NaN NaN
# 51063         놀람         NaN         NaN NaN NaN NaN NaN NaN NaN NaN
# 15790         슬픔         NaN         NaN NaN NaN NaN NaN NaN NaN NaN
# 25451         중립         NaN         NaN NaN NaN NaN NaN NaN NaN NaN
# 42784         중립         NaN         NaN NaN NaN NaN NaN NaN NaN NaN

# %%
chatbot_data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55629 entries, 0 to 55628
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10001 non-null  object
#  1   Unnamed: 1  55628 non-null  object
#  2   Unnamed: 2  55622 non-null  object
#  3   Unnamed: 3  0 non-null      float64
#  4   Unnamed: 4  0 non-null      float64
#  5   행복          1 non-null      float64
#  6   중립          0 non-null      float64
#  7   슬픔          0 non-null      float64
#  8   공포          0 non-null      float64
#  9   혐오          0 non-null      float64
#  10  분노          0 non-null      float64
#  11  놀람          0 non-null      float64
# dtypes: float64(9), object(3)
# memory usage: 5.1+ MB

# %%
chatbot_data_2.isnull().sum() # 결측치 확인
# Out:
# Unnamed: 0    45628
# Unnamed: 1        1
# Unnamed: 2        7
# Unnamed: 3    55629
# Unnamed: 4    55629
# 행복            55628
# 중립            55629
# 슬픔            55629
# 공포            55629
# 혐오            55629
# 분노            55629
# 놀람            55629
# dtype: int64

# %%
chatbot_data_2 = chatbot_data_2.iloc[1:, :3] # 필요없는 열 삭제
chatbot_data_2
# Out:
#       Unnamed: 0                                         Unnamed: 1 Unnamed: 2
# 1              S               아 진짜! 사무실에서 피지 말라니깐! 간접흡연이 얼마나 안좋은데!         분노
# 2            NaN       그럼 직접흡연하는 난 얼마나 안좋겠니? 안그래? 보면 꼭... 지 생각만 하고.         혐오
# 3            NaN                                            손님 왔어요.         중립
# 4            NaN                                            손님? 누구?         중립
# 5            NaN                                     몰라요. 팀장님 친구래요.         중립
# ...          ...                                                ...        ...
# 55624          S                                      얘긴 다 끝났냐? 원예부         중립
# 55625        NaN                   예. 그거 때문에, 부탁이 있......는......데요.         중립
# 55626        NaN                                   여자 숨겨달라는거면 사절이다.         중립
# 55627        NaN                                         아무래도 안되나요?         중립
# 55628        NaN  그 여자랑 내가 무슨 상관인데? 아까는 탐정님이 부탁하기에 너 구하는 김에 주워왔지...         중립
#
# [55628 rows x 3 columns]

# %%
chatbot_data_2[chatbot_data_2['Unnamed: 0'] =='S']
# Out:
#       Unnamed: 0                                  Unnamed: 1 Unnamed: 2
# 1              S        아 진짜! 사무실에서 피지 말라니깐! 간접흡연이 얼마나 안좋은데!         분노
# 8              S                              그래서... 무슨 일 해?         중립
# 16             S                              언제부터 시작할 수 있어?         중립
# 30             S                                       안 내켜.         혐오
# 42             S           집 짓는 이유가 그렇게 중요해? 왜, 내가 사기라도 칠까봐?         혐오
# ...          ...                                         ...        ...
# 55604          S  자네는 대체 뭘 하러 왔나! 젖은 생쥐 꼴이 된 나를 보면서 비웃으러 왔나?         분노
# 55609          S     조사결과에 따르면 의뢰인의 아버지는 횡령같은 걸 하지 않았다고 하는군.         중립
# 55614          S                                  그게 무슨 소리야?         중립
# 55619          S                  기억해 두게. 이 사건에서 사실은 필요치 않아.         중립
# 55624          S                               얘긴 다 끝났냐? 원예부         중립
#
# [10000 rows x 3 columns]

# %%
chatbot_data_2 = chatbot_data_2.iloc[:,1:] # Unnamed: 0 열 삭제
chatbot_data_2
# Out:
#                                               Unnamed: 1 Unnamed: 2
# 1                   아 진짜! 사무실에서 피지 말라니깐! 간접흡연이 얼마나 안좋은데!         분노
# 2           그럼 직접흡연하는 난 얼마나 안좋겠니? 안그래? 보면 꼭... 지 생각만 하고.         혐오
# 3                                                손님 왔어요.         중립
# 4                                                손님? 누구?         중립
# 5                                         몰라요. 팀장님 친구래요.         중립
# ...                                                  ...        ...
# 55624                                      얘긴 다 끝났냐? 원예부         중립
# 55625                   예. 그거 때문에, 부탁이 있......는......데요.         중립
# 55626                                   여자 숨겨달라는거면 사절이다.         중립
# 55627                                         아무래도 안되나요?         중립
# 55628  그 여자랑 내가 무슨 상관인데? 아까는 탐정님이 부탁하기에 너 구하는 김에 주워왔지...         중립
#
# [55628 rows x 2 columns]

# %%
chatbot_data_2['Unnamed: 2'].value_counts()
# Out:
# 중립     43786
# 놀람      4866
# 분노      3628
# 슬픔      1972
# 행복      1030
# 혐오       220
# 공포        98
# ㅍ         12
# 분          4
# ㅈ중립        1
# 분ㄴ         1
# 중림         1
# ㄴ중립        1
# 줄          1
# Name: Unnamed: 2, dtype: int64

# %%
chatbot_data_2[chatbot_data_2['Unnamed: 2'] == 'ㅍ'] # 확인
# Out:
#                                               Unnamed: 1 Unnamed: 2
# 25037                    인터넷에다 팔아야 되나.. 근데 너 이제 맘 잡았나보다?          ㅍ
# 27177                                     일부러 그럴 리가 있어요?          ㅍ
# 27948                                               그럼요?          ㅍ
# 28090                        샤프심이 없어서..가지러 왔다가 누나 보이길래..          ㅍ
# 28455                              아~ 자기소개서 쓰기 힘들어 죽겠어요~          ㅍ
# 28482                      원래 남자들..다른 남자랑 친하게 지내면 그러니까..          ㅍ
# 36684  그럼, 임마! 내가 누구냐? 한번 실수는 병가지상사다~이러시면서 나의 인간성과 품위...          ㅍ
# 37261                          처리 할거야. 처리해야지, 그게 돈이 얼만데?          ㅍ
# 37428                                  와, 어디서 꽁돈이라도 생겼나?          ㅍ
# 37864                                엄마, 엄만 결혼이 뭐 그리 좋아?          ㅍ
# 41755    앞으로는 어디서 우연히 마주쳐도 말 섞지 말자. 비위 상해. 너랑 말 하면.               ㅍ
# 43151                                      역시... 상처받았겠지?          ㅍ

# %%
chatbot_data_2[chatbot_data_2['Unnamed: 2'] == '분ㄴ'] # 확인
# Out:
#        Unnamed: 1 Unnamed: 2
# 817  근데 이 사람이 정말!         분ㄴ

# %%
chatbot_data_2[chatbot_data_2['Unnamed: 2'] == '분'] # 확인
# Out:
#                                      Unnamed: 1 Unnamed: 2
# 30290  지금 그쪽 사정 챙기게 생겼어? 우린 앉아서 그냥 내일 부도맞고? 어?!          분
# 35829                                      내놔요!          분
# 35831                                 얼른 안 내놔요!          분
# 51132                                    그만 자라.          분

# %%
# 90 이하인 카테고리 추출
value_counts = chatbot_data_2['Unnamed: 2'].value_counts()
categories_to_remove = value_counts[value_counts <= 90].index

# 해당 카테고리를 포함하지 않는 행만 선택
chatbot_data_2 = chatbot_data_2[~chatbot_data_2['Unnamed: 2'].isin(categories_to_remove)]

# %%
chatbot_data_2['Unnamed: 2'].value_counts()
# Out:
# 중립    43786
# 놀람     4866
# 분노     3628
# 슬픔     1972
# 행복     1030
# 혐오      220
# 공포       98
# Name: Unnamed: 2, dtype: int64

# %%
chatbot_data_2.columns =['Sentence', 'Emotion']

# %%
chatbot_data_2
# Out:
#                                                 Sentence Emotion
# 1                   아 진짜! 사무실에서 피지 말라니깐! 간접흡연이 얼마나 안좋은데!      분노
# 2           그럼 직접흡연하는 난 얼마나 안좋겠니? 안그래? 보면 꼭... 지 생각만 하고.      혐오
# 3                                                손님 왔어요.      중립
# 4                                                손님? 누구?      중립
# 5                                         몰라요. 팀장님 친구래요.      중립
# ...                                                  ...     ...
# 55624                                      얘긴 다 끝났냐? 원예부      중립
# 55625                   예. 그거 때문에, 부탁이 있......는......데요.      중립
# 55626                                   여자 숨겨달라는거면 사절이다.      중립
# 55627                                         아무래도 안되나요?      중립
# 55628  그 여자랑 내가 무슨 상관인데? 아까는 탐정님이 부탁하기에 너 구하는 김에 주워왔지...      중립
#
# [55607 rows x 2 columns]

# %%
chatbot_data_1['Emotion'].unique()
# Out:
# array(['공포', '놀람', '분노', '슬픔', '중립', '행복', '혐오'], dtype=object)

# %%
chatbot_data_2['Emotion'].unique()
chatbot_data_2 = chatbot_data_2.dropna(how='any')# Null 값 제거

# %%
chatbot_data_2['Emotion'].value_counts()
# Out:
# 중립    43786
# 놀람     4866
# 분노     3628
# 슬픔     1972
# 행복     1030
# 혐오      220
# 공포       98
# Name: Emotion, dtype: int64

# %%
chatbot_data_2[chatbot_data_2['Emotion'] == '중립'] # 확인
# Out:
#                                                 Sentence Emotion
# 3                                                손님 왔어요.      중립
# 4                                                손님? 누구?      중립
# 5                                         몰라요. 팀장님 친구래요.      중립
# 6                                           내 친구? 친구 누구?      중립
# 8                                         그래서... 무슨 일 해?      중립
# ...                                                  ...     ...
# 55624                                      얘긴 다 끝났냐? 원예부      중립
# 55625                   예. 그거 때문에, 부탁이 있......는......데요.      중립
# 55626                                   여자 숨겨달라는거면 사절이다.      중립
# 55627                                         아무래도 안되나요?      중립
# 55628  그 여자랑 내가 무슨 상관인데? 아까는 탐정님이 부탁하기에 너 구하는 김에 주워왔지...      중립
#
# [43786 rows x 2 columns]

# %%
len(chatbot_data_1), len(chatbot_data_2)
# Out:
# (38594, 55600)

# %%
df_data = pd.concat([chatbot_data_1,chatbot_data_2], ignore_index=True)
df_data
# Out:
#                                                 Sentence Emotion
# 0                               언니 동생으로 부르는게 맞는 일인가요..??      공포
# 1                                           그냥 내 느낌일뿐겠지?      공포
# 2                                         아직너무초기라서 그런거죠?      공포
# 3                                          유치원버스 사고 낫다던데      공포
# 4                                            근데 원래이런거맞나요      공포
# ...                                                  ...     ...
# 94189                                      얘긴 다 끝났냐? 원예부      중립
# 94190                   예. 그거 때문에, 부탁이 있......는......데요.      중립
# 94191                                   여자 숨겨달라는거면 사절이다.      중립
# 94192                                         아무래도 안되나요?      중립
# 94193  그 여자랑 내가 무슨 상관인데? 아까는 탐정님이 부탁하기에 너 구하는 김에 주워왔지...      중립
#
# [94194 rows x 2 columns]

# %%
df_data.drop_duplicates(['Sentence', 'Emotion'],inplace=True) # 중복행 제거
df_data = df_data.reset_index(drop=True)
df_data
# Out:
#                                                 Sentence Emotion
# 0                               언니 동생으로 부르는게 맞는 일인가요..??      공포
# 1                                           그냥 내 느낌일뿐겠지?      공포
# 2                                         아직너무초기라서 그런거죠?      공포
# 3                                          유치원버스 사고 낫다던데      공포
# 4                                            근데 원래이런거맞나요      공포
# ...                                                  ...     ...
# 90090                                      얘긴 다 끝났냐? 원예부      중립
# 90091                   예. 그거 때문에, 부탁이 있......는......데요.      중립
# 90092                                   여자 숨겨달라는거면 사절이다.      중립
# 90093                                         아무래도 안되나요?      중립
# 90094  그 여자랑 내가 무슨 상관인데? 아까는 탐정님이 부탁하기에 너 구하는 김에 주워왔지...      중립
#
# [90095 rows x 2 columns]

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90095 entries, 0 to 90094
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sentence  90095 non-null  object
#  1   Emotion   90095 non-null  object
# dtypes: object(2)
# memory usage: 1.4+ MB

# %%
# df_data.to_csv('final_dataset.csv',header=True,index=False)

# %%
import pandas as pd
df_data = pd.read_csv('/content/final_dataset.csv')
df_data
# Out:
#                                                 Sentence Emotion
# 0                               언니 동생으로 부르는게 맞는 일인가요..??      공포
# 1                                           그냥 내 느낌일뿐겠지?      공포
# 2                                         아직너무초기라서 그런거죠?      공포
# 3                                          유치원버스 사고 낫다던데      공포
# 4                                            근데 원래이런거맞나요      공포
# ...                                                  ...     ...
# 90090                                      얘긴 다 끝났냐? 원예부      중립
# 90091                   예. 그거 때문에, 부탁이 있......는......데요.      중립
# 90092                                   여자 숨겨달라는거면 사절이다.      중립
# 90093                                         아무래도 안되나요?      중립
# 90094  그 여자랑 내가 무슨 상관인데? 아까는 탐정님이 부탁하기에 너 구하는 김에 주워왔지...      중립
#
# [90095 rows x 2 columns]

# %% [markdown]
# ## 1. 중립 데이터 제거

# %%
df_data_neut = df_data[df_data['Emotion'] == '중립'] # 확인

# %%
df_data_drop = df_data[df_data['Emotion'] != '중립']
df_data_drop # 중복 데이터 제거한 데이터
# Out:
#                                          Sentence Emotion
# 0                        언니 동생으로 부르는게 맞는 일인가요..??      공포
# 1                                    그냥 내 느낌일뿐겠지?      공포
# 2                                  아직너무초기라서 그런거죠?      공포
# 3                                   유치원버스 사고 낫다던데      공포
# 4                                     근데 원래이런거맞나요      공포
# ...                                           ...     ...
# 94119                                    그 눈은 뭔데?      분노
# 94132                              뭐? 다시 한 번 말해봐.      분노
# 94152                                     어? 정말요?      놀람
# 94154                         혹시, 다들 은행 계좌없는 거예요?      놀람
# 94169  자네는 대체 뭘 하러 왔나! 젖은 생쥐 꼴이 된 나를 보면서 비웃으러 왔나?      분노
#
# [44454 rows x 2 columns]

# %%
len(df_data), len(df_data_neut)+len(df_data_drop) # 확인
# Out:
# (90095, 90095)

# %%
df_data = df_data_drop

# %%
target_classes ={
    '공포': 0,
    '놀람': 1,
    '분노': 2,
    '슬픔': 3,
    # '중립': 4,
    '행복': 4,
    '혐오': 5
  }
